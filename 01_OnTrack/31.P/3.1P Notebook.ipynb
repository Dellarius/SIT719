# %% [markdown]
# ## SIT719 Security and Privacy Issues in Analytics
# ---
# ### Pass Task 3.1: Collection of scikit-learn commands for machine learning
#
# This notebook demonstrates how to use scikit-learn for machine learning in Python, covering three senarios:
#
# - Anomaly detection

# %% [markdown]
# import pandas

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report   
import matplotlib.pyplot as plt
