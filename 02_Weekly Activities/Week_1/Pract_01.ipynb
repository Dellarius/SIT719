# %%
print('Hello, World!')
# Out:
# Hello, World!

# %%
text = "Hello, World!"
print(text)
# Out:
# Hello, World!

# %%
multiline = '''This is a test for multiline. This is the first tile
This is the second line
I Asked, "What's your name?"'''

print(multiline)
# Out:
# This is a test for multiline. This is the first tile
# This is the second line
# I Asked, "What's your name?"

# %%
multiline
# Out:
# 'This is a test for multiline. This is the first tile\nThis is the second line\nI Asked, "What\'s your name?"'

# %%
string = 'What\'s your name?'
print(string)
# Out:
# What's your name?

# %%
path = 'c:\\windows\\temp'
print(path)
# Out:
# c:\windows\temp

# %%
multiline = 'This is a test for multiline. This is the first line.\nThis is the second line.'
print(multiline)
# Out:
# This is a test for multiline. This is the first line.
# This is the second line.

# %%
print('Hello, ' + 'World' * 3)
# Out:
# Hello, WorldWorldWorld

# %%
name = 'World'
greeting = 'Hello'
print(greeting + ', ' + name + '!')
# Out:
# Hello, World!

# %%
2 + 3
# Out:
# 5

# %%
3 * 5
# Out:
# 15

# %%
3 ** 4
# Out:
# 81

# %%
3 * 3 * 3 * 3
# Out:
# 81

# %%
14 / 5
# Out:
# 2.8

# %%
14 // 5
# Out:
# 2

# %%
14 % 5
# Out:
# 4

# %%
-14 % 5
# Out:
# 1

# %%
type('Hello, world!)')

input_Value = '45.6'
type(input_Value)

weight = float(input_Value)
weight
type(weight)

input_Value = 'David'
weight = float(input_Value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 11
#       8 type(weight)
#      10 input_Value = 'David'
# ---> 11 weight = float(input_Value)
#
# ValueError: could not convert string to float: 'David'

# %%
'cat' < 'Dog'
# Out:
# False

# %%
# AND Gate
3 < 4  and 7 < 8
# Out:
# True

# %%
# OR Gate
3 < 4  or 7 > 8
# Out:
# True

# %%
# NOT Gate
not ((3 > 4) or (7 > 8))
# Out:
# True

# %%
print('Output a float number: %10.4f' % (3.5))

print('Output an integer: %+05d' % (23))
# Out:
# Output a float number:     3.5000
# Output an integer: +0023
